# %%
import juliacall
import numpy as np
import fit_modeler
import evolve_binary
import pandas as pd
from astropy import units as u
from astropy import constants as const

np.set_printoptions(legacy='1.13')

# %%
population = np.loadtxt('/Users/vdelfave/Repos/mcfacts/runs/gal00/output_mergers.dat')

# %%
galaxy, bin_orb_a, mass_final, chi_eff, spin_final, spin_angle_final, mass_1, mass_2, spin_1, spin_2, spin_angle_1, spin_angle_2, gen_1, gen_2, time_merged, chi_p, time_inspiral_flagged, bin_sep_flagged = population.T

# %%
bin_orb_inc = [0, 0, 1]

# %%
# No longer needed since new surrogate model intakes individual mass values and not the mass ratio

'''#sorting mass ratios
mass_1 = []
mass_2 = []
for i in range(len(population['mass_1'])):
    if population['mass_1'][i] > population['mass_2'][i]:
        mass_1.append(population['mass_1'][i])
        mass_2.append(population['mass_2'][i])
    else:
        mass_1.append(population['mass_2'][i])
        mass_2.append(population['mass_1'][i])
print(mass_1)
print(mass_2)'''
# Out:
# "#sorting mass ratios\nmass_1 = []\nmass_2 = []\nfor i in range(len(population['mass_1'])):\n    if population['mass_1'][i] > population['mass_2'][i]:\n        mass_1.append(population['mass_1'][i])\n        mass_2.append(population['mass_2'][i])\n    else:\n        mass_1.append(population['mass_2'][i])\n        mass_2.append(population['mass_1'][i])\nprint(mass_1)\nprint(mass_2)"

# %%
test = [[], [], []]
for i in range(len(test)):
    #test[i].append(i)
    test[0].append(i**1)
    #y
    test[1].append(i**2)
    #z
    test[2].append(i**3)
print(test)
# Out:
# [[0, 1, 2], [0, 1, 4], [0, 1, 8]]

# %%
# Converting spin_1 magnitude values into cartesian values
chiA_components = [[] for _ in range(len(spin_1))] 
theta = 0.0

for i in range(len(chiA_components)):
    #x component
    chiA_components[i].append(spin_1[i] * np.cos(theta))
    #y
    chiA_components[i].append(spin_1[i] * np.sin(theta))
    #z
    chiA_components[i].append(np.sqrt((chiA_components[i][0])**2.0 + (chiA_components[i][1])**2.0))
    
print(chiA_components)
# Out:
# [[0.13666666103773112, 0.0, 0.13666666103773112], [-0.00082124062158562671, -0.0, 0.00082124062158562671], [0.094125356723099948, 0.0, 0.094125356723099948], [0.20445188324217659, 0.0, 0.20445188324217659], [0.12853244870516123, 0.0, 0.12853244870516123], [-0.16267330344358816, -0.0, 0.16267330344358816], [-0.13346631077772159, -0.0, 0.13346631077772159], [-0.10063428797203931, -0.0, 0.10063428797203931], [0.68545858526875503, 0.0, 0.68545858526875503], [0.026336307281124384, 0.0, 0.026336307281124384], [0.021422696066163108, 0.0, 0.021422696066163108], [0.14338165866862088, 0.0, 0.14338165866862088], [-0.15410973906274358, -0.0, 0.15410973906274358], [0.069707405922282945, 0.0, 0.069707405922282945], [0.09366374981762364, 0.0, 0.09366374981762364], [0.68101702308823764, 0.0, 0.68101702308823764], [-0.11248233847223189, -0.0, 0.11248233847223189], [0.67944317460613968, 0.0, 0.67944317460613968], [0.016079955194088162, 0.0, 0.016079955194088162], [0.056865141056076561, 0.0, 0.056865141056076561], [-0.080767223905907043, -0.0, 0.080767223905907043], [-0.046475424773328278, -0.0, 0.046475424773328278], [0.64149278372429686, 0
691], [0.012596448922660389, 0.0, 0.012596448922660389], [0.75259269875978041, 0.0, 0.75259269875978041], [0.12687906904114196, 0.0, 0.12687906904114196], [-0.18225057751957274, -0.0, 0.18225057751957274], [0.70305997065705106, 0.0, 0.70305997065705106], [0.79289955340182516, 0.0, 0.79289955340182516], [0.52856715045491443, 0.0, 0.52856715045491443], [-0.21090678260471646, -0.0, 0.21090678260471646], [0.029539756520591699, 0.0, 0.029539756520591699], [0.52639458597395916, 0.0, 0.52639458597395916], [-0.16089163782970545, -0.0, 0.16089163782970545], [0.87260598904870645, 0.0, 0.87260598904870645], [0.91054995213519929, 0.0, 0.91054995213519929], [0.68908706357404237, 0.0, 0.68908706357404237], [-0.089798278679107321, -0.0, 0.089798278679107321], [0.92817852009061608, 0.0, 0.92817852009061608], [0.074007256327584078, 0.0, 0.074007256327584078], [0.57989004469840966, 0.0, 0.57989004469840966], [0.85154941639117132, 0.0, 0.85154941639117132], [-0.099912402309842746, -0.0, 0.099912402309842746], [0.04146553135665651, 0.0, 0.04146553135665651], [0.89814616020665039, 0.0, 0.89814616020665039], [0.70460837974559909, 0.0, 0.70460837974559909], [0.694240468096473, 0.0, 0.694240468096473], [-0.0062085010503853963, -0.0, 0.0062085010503853963], [0.97999999999999998, 0.0, 0.97999999999999998], [0.012925460403745214, 0.0, 0.012925460403745214], [0.87560511443601252, 0.0, 0.87560511443601252], [0.96675580178268172, 0.0, 0.96675580178268172], [0.20476918729746957, 0.0, 0.20476918729746957], [-0.0071653193248253028, -0.0, 0.0071653193248253028], [0.73936173687618456, 0.0, 0.73936173687618456], [-0.014366952432340978, -0.0, 0.014366952432340978], [0.89089637811294298, 0.0, 0.89089637811294298], [0.95014747120482912, 0.0, 0.95014747120482912], [0.88798413639433182, 0.0, 0.88798413639433182], [0.97999999999999998, 0.0, 0.97999999999999998], [0.61447336840319911, 0.0, 0.61447336840319911], [0.62600136098741166, 0.0, 0.62600136098741166], [0.0097737719125916417, 0.0, 0.0097737719125916417], [0.97999999999999998, 0.0, 0.97999999999999998], [-0.10528708605185806, -0.0, 0.10528708605185806]]

# %%
population['mass_1'][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 population['mass_1'][0]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
print(population['spin_angle_1'][0] - population['spin_angle_2'][0])
# Out:
# 0.460558847882

# %%
for i in range(len(population['mass_1'])):
    mass_1 = population['mass_1'][i]
    mass_2 = population['mass_2'][i]
    spin_1 = population['spin_1'][i]
    spin_2 = population['spin_2'][i]
    spin_angle_1 = population['spin_angle_1'][i]
    spin_angle_2 = population['spin_angle_2'][i]
    phi_12 = population['spin_angle_2'][i] - population['spin_angle_1'][i]
    bin_sep = population['bin_sep'][i] * (1.e8 / (mass_1 + mass_2))
    bin_orb_inc = [0, 0, 1]

# %%
print("sur")
surrogate = fit_modeler.GPRFitters.read_from_file(f"surrogate.joblib")
# Out:
# sur

# %%
parameters = [mass_1, mass_2, spin_1, spin_2, spin_angle_1, spin_angle_2, phi_12, bin_sep, bin_orb_inc]
for i in parameters:
    print(i)
    print("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 parameters = [mass_1, mass_2, spin_1, spin_2, spin_angle_1, spin_angle_2, phi_12, bin_sep, bin_orb_inc]
#       2 for i in parameters:
#       3     print(i)
#
# NameError: name 'phi_12' is not defined

# %%
print("e")
M_f, spin_f, v_f = evolve_binary.evolve_binary(
    mass_1,
    mass_2,
    spin_1,
    spin_2,
    spin_angle_1,
    spin_angle_2,
    spin_angle_2 - spin_angle_1,
    bin_sep_flagged,
    bin_orb_inc,
    surrogate,
    True,
)

print("M_f = ", M_f)
print("spin_f = ", spin_f)
print("v_f = ", v_f)
# Out:
# e
# Evolving binary...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 print("e")
# ----> 2 M_f, spin_f, v_f = evolve_binary.evolve_binary(
#       3     mass_1,
#       4     mass_2,
#       5     spin_1,
#       6     spin_2,
#       7     spin_angle_1,
#       8     spin_angle_2,
#       9     spin_angle_2 - spin_angle_1,
#      10     bin_sep_flagged,
#      11     bin_orb_inc,
#      12     surrogate,
#      13     True,
#      14 )
#      16 print("M_f = ", M_f)
#      17 print("spin_f = ", spin_f)
#
# File ~/Repos/mcfacts/src/mcfacts/external/evolve_binary/evolve_binary.py:415, in evolve_binary(mass_1, mass_2, spin_1, spin_2, spin_angle_1, spin_angle_2, phi_12, bin_sep, bin_orb_inc, surrogate, verbose)
#     402 chi_2 = (
#     403     spin_2
#     404     / mass_2**2
#    (...)
#     411     )
#     412 )
#     414 # Flip labels, if necessary
# --> 415 if mass_1 < mass_2:
#     416     if verbose:
#     417         print("mass_1 < mass_2! Flipping black hole labels.")
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# We have time to merger in years
time_to_merger_gw = time_inspiral_flagged * u.s
#time_to_merger_gw = time_to_merger_gw.to("yr")
#bin_sep = (time_to_merger_gw * (const.c**3/const.G)).to('solMass').value
bin_sep = bin_sep_flagged * (1.e8 / (mass_1 + mass_2))
print(time_to_merger_gw)
print(time_to_merger_gw.to('yr'))
print(bin_sep)
# Out:
# [  1.30792864e+06   1.45817343e+10   4.90900913e+11   1.53461234e+11
#    1.81119779e+09   2.48345823e+10   9.66806708e-11   1.12171138e+03
#    1.68583642e+13   7.24546036e+07   3.71986501e+09   2.30062811e+07
#    4.64541127e+12   2.86771415e+08   3.96656182e+11   2.36687059e+11
#    9.96407750e+07   5.39428065e-14   5.49404634e+12   7.79997048e+07
#    2.57509278e+02   6.34795830e+07   3.48546825e+06   2.96005094e+02
#    3.40066780e-31   2.84486690e+11   5.08127492e-15   1.89642110e+08
#    7.53401162e+09   9.49921368e+09   7.39164892e+02   1.07186064e+14
#    2.19141240e-22   2.92820684e+06   4.08025968e-18   7.10347146e+04
#    8.94026775e+03   1.04214335e-18   1.74569879e-05   1.99743006e+11
#    3.56207088e-18   4.52083804e+03   9.64175027e-11   2.13713134e+13
#    8.25347308e+09   3.88563980e+08   6.77615225e+01   2.33611148e+12
#    6.03582305e+05   9.63208501e-10   2.26566226e+01   1.92777144e+02
#    2.02666897e+06   1.60883392e+07   1.22866780e+05   9.17448710e+12
#    2.54298088e-02   1.70110531e+01   3.24229322e+09] s
# [  4.14457577e-02   4.62067277e+02   1.55557112e+04   4.86289306e+03
#    5.73933945e+01   7.86960424e+02   3.06362559e-18   3.55448887e-05
#    5.34209324e+05   2.29594784e+00   1.17875409e+02   7.29025057e-01
#    1.47204200e+05   9.08723779e+00   1.25692759e+04   7.50016030e+03
#    3.15742563e+00   1.70934439e-21   1.74095823e+05   2.47166150e+00
#    8.15997661e-06   2.01154660e+00   1.10447824e-01   9.37983541e-06
#    1.07760660e-38   9.01483920e+03   1.61015886e-22   6.00939582e+00
#    2.38738422e+02   3.01011917e+02   2.34227220e-05   3.39652142e+06
#    6.94416684e-30   9.27892755e-02   1.29295627e-25   2.25095428e-03
#    2.83299989e-04   3.30235299e-26   5.53178566e-13   6.32947393e+03
#    1.12875215e-25   1.43256713e-04   3.05528629e-18   6.77216055e+05
#    2.61536780e+02   1.23128495e+01   2.14723307e-06   7.40269057e+04
#    1.91263691e-02   3.05222356e-17   7.17945046e-07   6.10873908e-06
#    6.42212643e-02   5.09808706e-01   3.89341331e-03   2.90721953e+05
#    8.05822015e-10   5.39047744e-07   1.02742072e+02] yr
# [  5.75341011e+04   3.66398068e+06   2.00000000e+00   8.81445027e+05
#    3.06295783e+05   1.53001033e+06   3.40209545e+07   8.18025272e+03
#    2.00000000e+00   1.95303815e+05   6.27504439e+05   1.61559346e+05
#    2.00000000e+00   7.56001567e+05   2.00000000e+00   9.79446701e+05
#    1.36675401e+05   5.25214515e+06   2.00000000e+00   1.99493721e+05
#    9.44915878e+03   1.52018532e+05   6.13027648e+04   5.49835111e+03
#    2.59691128e+02   1.09364775e+06   2.00000000e+00   2.04930888e+05
#    3.96907569e+05   1.01332184e+06   8.36226355e+03   2.00000000e+00
#    3.41296559e+04   4.66335102e+04   4.33874298e+05   4.17289931e+04
#    2.09210602e+04   3.25330353e+05   9.88693235e+01   1.26459639e+06
#    4.14120606e+05   1.17925413e+04   3.08995638e+00   2.00000000e+00
#    1.71349306e+06   1.28417462e+06   1.10083686e+04   2.00000000e+00
#    8.74570603e+04   2.75753726e+01   3.96752056e+03   6.49171681e+04
#    5.42990720e+04   5.74513953e+04   2.21464508e+04   2.00000000e+00
#    4.64669854e+02   2.44064907e+03   1.93143535e+05]

# %%
import time

# %%
for i in range(len(mass_1)):
    print("mass_1 = ",mass_1[i])
    print("mass_2 = ",mass_2[i])
    print("bin_sep = ",bin_sep[i])
    start = time.time()
    M_f, spin_f, v_f = evolve_binary.evolve_binary(
        mass_1[i],
        mass_2[i],
        spin_1[i],
        spin_2[i],
        spin_angle_1[i],
        spin_angle_2[i],
        spin_angle_2[i] - spin_angle_1[i],
        bin_sep[i],
        [0,0,1],
        surrogate,
        True,
    )
    end = time.time()
    
    run_time = end - start

    mass_final.append(M_f)
    spin_final.append(spin_f)
    velocity_final.append(v_f)
    
    print("M_f = ", M_f)
    print("spin_f = ", spin_f)
    print("v_f = ", v_f)
    print("Merger took ", run_time, " seconds")

# %%
print(bin_sep)
# Out:
# 0    3.929177e+08
# 1    7.774826e+07
# 2    1.320129e+08
# 3    1.298442e+08
# dtype: float64

# %%
print(mass_final[-1])
print(spin_final[-1])
print(velocity_final[-1])
# Out:
# 65.4291225742
# [  4.38346003e-01   3.82077660e-01   2.03482924e+03]
# [ -1.07519672e-04   5.42113865e-04   6.99717987e-07]
