# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u
import astropy.constants as const

# %%
def primary_drag_force_components_base(mach_number):
	radial_component = 0.3 * (mach_number ** 2)
	azimuthal_component = np.log(10 / ((0.11 * mach_number) + 1.65))
	
	if mach_number < 6.2:
		radial_component = 4 + (mach_number ** 2) * (np.e ** -(mach_number - 7)) * np.sin( ((mach_number - 4.4) / 4)) / 5
	
	if 1.1 <= mach_number < 4.4:
		radial_component = 0.5 * np.log(9.33 * (mach_number ** 2) * (mach_number ** 2 - 0.95))
	if 1.0 <= mach_number < 4.4:
		azimuthal_component = np.log(3300 * ((mach_number - 0.71) ** 5.72) * (mach_number ** -9.58))
		
	if mach_number < 1.1:
		radial_component = (mach_number ** 2) * (10 ** ((3.51 * mach_number) - 4.22))	
	if mach_number < 1.0:
		azimuthal_component = 0.7706 * np.log((1 + mach_number) / (1.0004 - 0.9185 * mach_number)) - 1.4703 * mach_number
		
	if mach_number <= 0.0523352:
		azimuthal_component = 0.0
		
	return radial_component, azimuthal_component

primary_drag_force_components = np.vectorize(primary_drag_force_components_base)

def secondary_drag_force_components_base(mach_number):
	radial_component = 0.56 - (0.027 * (mach_number + ((mach_number - 6) ** -1)))
	azimuthal_component = -0.13 + 0.07 * np.arctan((5 * mach_number) - 15)
	
	if 2.97 <= mach_number < 6.2:
		radial_component = 0.76 - (0.08 * (mach_number + ((mach_number - 2.76) ** -1)))
		
	if mach_number < 2.97:
		radial_component = 0.5 - (0.43 * (1 - np.cosh(2.2 * mach_number) ** -0.36))
		azimuthal_component = -0.022 * (10 - mach_number) * np.tanh(3 * mach_number / 2)

	radial_component *= mach_number ** 2
	azimuthal_component *= mach_number ** 2

	return radial_component, azimuthal_component

secondary_drag_force_components = np.vectorize(secondary_drag_force_components_base)

# %%
mach = np.linspace(0, 8, 1000)

prime = primary_drag_force_components(mach)
second = secondary_drag_force_components(mach)

# %%
plt.plot(mach, (prime[0] + second[0]) / mach ** 2, c='blue')
plt.plot(mach, (prime[1] + second[1]) / mach ** 2, c='red')

plt.plot(mach, prime[0] / mach ** 2, c='blue', linestyle="dashed")
plt.plot(mach, second[0] / mach ** 2, c='blue', linestyle="dotted")

plt.plot(mach, prime[1] / mach ** 2, c='red', linestyle="dashed")
plt.plot(mach, second[1] / mach ** 2, c='red', linestyle="dotted")

plt.ylim((-0.3,1.8))
plt.xlim((0, 8))

plt.ylabel("$\mathcal{I}/\mathcal{M}^2$")
plt.xlabel("$\mathcal{M}$")

plt.savefig("kimkim.pdf")
# Out:
# /var/folders/ll/v1xt8w0j7bn55wn96smz2wtc0000gn/T/ipykernel_50006/9521125.py:1: RuntimeWarning: invalid value encountered in divide
#   plt.plot(mach, (prime[0] + second[0]) / mach ** 2, c='blue')
# /var/folders/ll/v1xt8w0j7bn55wn96smz2wtc0000gn/T/ipykernel_50006/9521125.py:2: RuntimeWarning: invalid value encountered in divide
#   plt.plot(mach, (prime[1] + second[1]) / mach ** 2, c='red')
# /var/folders/ll/v1xt8w0j7bn55wn96smz2wtc0000gn/T/ipykernel_50006/9521125.py:4: RuntimeWarning: invalid value encountered in divide
#   plt.plot(mach, prime[0] / mach ** 2, c='blue', linestyle="dashed")
# /var/folders/ll/v1xt8w0j7bn55wn96smz2wtc0000gn/T/ipykernel_50006/9521125.py:5: RuntimeWarning: invalid value encountered in divide
#   plt.plot(mach, second[0] / mach ** 2, c='blue', linestyle="dotted")
# /var/folders/ll/v1xt8w0j7bn55wn96smz2wtc0000gn/T/ipykernel_50006/9521125.py:7: RuntimeWarning: invalid value encountered in divide
# ...

# %%
def drag_forces(mass, velocity, density, sound_speed, func_drag_force_components):
	mach_number = velocity / sound_speed
	drag_force_components = func_drag_force_components(mach_number.value)
	force_component = (4 * np.pi * density) * (((const.G * mass) / velocity) ** 2)
	
	return (-force_component * drag_force_components[0]), (-force_component * drag_force_components[1])

# %%
# Out:
# (<Quantity [            nan, -1.42279143e+21, -1.51792163e+21,
#            -1.61941239e+21, -1.72768899e+21, -1.84320514e+21,
#            -1.96644489e+21, -2.09792466e+21, -2.23819539e+21,
#            -2.38784485e+21, -2.54750012e+21, -2.71783021e+21,
#            -2.89954885e+21, -3.09341750e+21, -3.30024852e+21,
#            -3.52090862e+21, -3.75632241e+21, -4.00747637e+21,
#            -4.27542289e+21, -4.56128476e+21, -4.86625983e+21,
#            -5.19162604e+21, -5.53874678e+21, -5.90907658e+21,
#            -6.30416725e+21, -6.72567434e+21, -7.17536409e+21,
#            -7.65512085e+21, -8.16695493e+21, -8.71301110e+21,
#            -9.29557748e+21, -9.91709523e+21, -1.05801687e+22,
#            -1.12875763e+22, -1.20422824e+22, -1.28474494e+22,
#            -1.37064512e+22, -1.46228873e+22, -1.56005978e+22,
#            -1.66436797e+22, -1.77565037e+22, -1.89437330e+22,
#            -2.02103425e+22, -2.15616395e+22, -2.30032865e+22,
# ...

# %%
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# Fixed parameters
m1 = 10 * const.M_sun.si
cs = (1e7 * (u.cm / u.s)).si          # sg-disk @ ~200 rg
rho = (1e-11 * (u.g / u.cm ** 3)).si  # sg-disk @ ~200 rg
v = (np.linspace(0, 8e7, 1000) * (u.cm / u.s)).si

# q = m_secondary / m_primary (primary = larger mass)
# m1 held at 10; m2 = m1 / q
# q = 1.0 -> m2 = 10,  q = 0.5 -> m2 = 20,  q = 0.1 -> m2 = 100
mass_ratios = np.linspace(1.0, 0.3, 10)

norm = mcolors.Normalize(vmin=mass_ratios.min(), vmax=mass_ratios.max())
cmap = cm.get_cmap('jet_r')

fig, ax = plt.subplots()

for q in mass_ratios:
    m2 = m1 / q

    prime_df = drag_forces(m1, v, rho, cs, primary_drag_force_components)
    secondary_df = drag_forces(m2, v, rho, cs, secondary_drag_force_components)

    azimuthal = secondary_df[1] + prime_df[1]

    ax.plot(v / cs, azimuthal, color=cmap(norm(q)), label=f"q = {q:.2f}")

ax.hlines(0, 0, 10, colors='white', linestyle='dashed')

ax.set_xlim((0, 4))
ax.set_ylabel("Force ($N$)")
ax.set_xlabel("Mach Number ($V/c_s$)")

sm = cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label("Mass ratio $q = m_2/m_1$")

plt.savefig("massratio.svg")
plt.show()
# Out:
# /var/folders/ll/v1xt8w0j7bn55wn96smz2wtc0000gn/T/ipykernel_50006/1776545131.py:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('jet_r')

# %%
 def change_in_separation(initial_separation, initial_velocity, drag_force, primary_mass, secondary_mass):
	return - (((initial_separation ** 2) * initial_velocity * (drag_force + drag_force)) / (const.G * primary_mass * secondary_mass))

def test_change_in_separation(initial_separation, primary_mass, secondary_mass, primary_drag_force, secondary_drag_force):
    primary_acceleration = primary_drag_force / primary_mass
    secondary_acceleration = secondary_drag_force / secondary_mass

    binary_mass = primary_mass + secondary_mass

    return np.sqrt((const.G * binary_mass) / (((const.G * binary_mass) / (binary_separation ** 2)) + primary_acceleration + secondary_acceleration)) - initial_separation

def alt_change_in_separation(initial_separation, primary_mass, secondary_mass, primary_drag_force, secondary_drag_force):
    primary_acceleration = primary_drag_force / primary_mass
    secondary_acceleration = secondary_drag_force / secondary_mass

    binary_mass = primary_mass + secondary_mass

    orbital_velocity_comp = np.sqrt((const.G * binary_mass) / initial_separation) / initial_separation

    orbital_acceleration_comp = (np.sqrt((const.G * binary_mass) / initial_separation) ** 2) / initial_separation ** 2

    #print(primary_acceleration, secondary_acceleration)

    #print(orbital_acceleration_comp)
    #print(orbital_acceleration_comp * initial_separation)

    return (primary_acceleration + secondary_acceleration - (orbital_acceleration_comp * initial_separation)) / (2 * orbital_velocity_comp)

# %%
# separations = []
#
# binary_separation = (1 * u.pc).si #((const.G * (m1 + m2)) / (const.c ** 2)) * 6
#
# for i in range(100000):
#     orbital_velocity = np.sqrt((const.G * (m1 + m2)) / binary_separation)
#
#     prime_df = drag_forces(m1, orbital_velocity, rho, cs, primary_drag_force_components)
#     secondary_df = drag_forces(m2, orbital_velocity, rho, cs, secondary_drag_force_components)
#
#     total_df = np.sqrt((prime_df[0] + secondary_df[0]) ** 2 + (prime_df[1] + secondary_df[1]) ** 2)
#
#     #delta_sep = change_in_separation(binary_separation, orbital_velocity, total_df, m1, m1)
#     delta_sep = alt_change_in_separation(binary_separation, m1, m2, prime_df[1], secondary_df[1])
#     #delta_sep = test_change_in_separation(binary_separation, m1, m2, prime_df[1], secondary_df[1])
#
#     #print(f"{orbital_velocity}, {binary_separation}, {total_df}, {delta_sep}, {(delta_sep / const.c) * 100}")
#
#     separations.append(binary_separation.value)
#
#     binary_separation += (delta_sep * ((100 * u.yr).to(u.s)))
#
#     if i % 1000 == 0:
#         print (delta_sep * ((100 * u.yr).to(u.s)))
#         print (binary_separation)
#
#     if np.isnan(binary_separation):
#         break

# %%
separations = []

binary_separation = (3.276065172865173008e+04 * (const.G * 1e8 * u.M_sun / const.c ** 2)).si #((const.G * (m1 + m2)) / ((cs * 1.4) ** 2))

timestep = 100

for i in range(20000):
    orbital_velocity = np.sqrt((const.G * (m1 + m2)) / binary_separation)

    prime_df = drag_forces(m1, orbital_velocity, rho, cs, primary_drag_force_components)
    secondary_df = drag_forces(m2, orbital_velocity, rho, cs, secondary_drag_force_components)

    total_df = np.sqrt((prime_df[0] + secondary_df[0]) ** 2 + (prime_df[1] + secondary_df[1]) ** 2)
    total_accel_phi = (prime_df[1] + secondary_df[1]) / (m1 + m2)
    total_accel_r = (prime_df[0] + secondary_df[0]) / (m1 + m2)

    new_velocity = orbital_velocity + (total_accel_phi * ((timestep * u.yr).to(u.s)))

    new_separation = ((const.G * (m1 + m2)) / (new_velocity ** 2))

    if i % 10 == 0:
        print(orbital_velocity, new_velocity, new_separation, orbital_velocity / cs)

    separations.append(new_separation.value)
    binary_separation = new_separation

    if np.isnan(binary_separation):
        break
# Out:
# 740.729147432289 m / s 745.0189260722249 m / s 4781971888488917.0 m 0.00740729147432289
# 784.7613394538965 m / s 789.3058982082691 m / s 4260405467780633.0 m 0.007847613394538966
# 831.4085788636326 m / s 836.2230201396673 m / s 3795748174134223.0 m 0.008314085788636325
# 880.8258587990382 m / s 885.9261763009772 m / s 3381789426142655.5 m 0.008808258587990381
# 933.1773172822913 m / s 938.5804480775166 m / s 3012996475456201.5 m 0.009331773172822912
# 988.6367710978362 m / s 994.3606506482373 m / s 2684440423448354.0 m 0.009886367710978363
# 1047.3882800255917 m / s 1053.4519003416276 m / s 2391730313126231.0 m 0.010473882800255917
# 1109.6267430336643 m / s 1116.050214115107 m / s 2130954414865393.5 m 0.011096267430336643
# 1175.558528099655 m / s 1182.363142833479 m / s 1898627920757442.2 m 0.01175558528099655
# 1245.4021373939738 m / s 1252.610440086217 m / s 1691646348065738.5 m 0.012454021373939738
# ...

# %%
fig, (ax1, ax2) = plt.subplots(2)

ax1.plot(np.sqrt((const.G * (m1 + m2)) / (separations * u.m))/cs)
ax1.set_ylabel("Mach Number [$v/c_s$]")

ax2.plot(separations)
ax2.set_yscale('log')
ax2.set_ylabel("Binary Separation [$r/r_0$]")

plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')
