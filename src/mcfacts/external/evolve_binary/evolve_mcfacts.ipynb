# %%
import juliacall
import numpy as np
import fit_modeler
import evolve_binary
import pandas as pd

np.set_printoptions(legacy='1.13')
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
population = np.loadtxt('/Users/vdelfave/Repos/mcfacts/runs/gal00/output_mergers.dat')

# %%
galaxy, bin_orb_a, mass_final, chi_eff, spin_final, spin_angle_final, mass_1, mass_2, spin_1, spin_2, spin_angle_1, spin_angle_2, gen_1, gen_2, time_merged = population.T

# %%
# No longer needed since new surrogate model intakes individual mass values and not the mass ratio

'''#sorting mass ratios
mass_1 = []
mass_2 = []
for i in range(len(population['mass_1'])):
    if population['mass_1'][i] > population['mass_2'][i]:
        mass_1.append(population['mass_1'][i])
        mass_2.append(population['mass_2'][i])
    else:
        mass_1.append(population['mass_2'][i])
        mass_2.append(population['mass_1'][i])
print(mass_1)
print(mass_2)'''
# Out:
# "#sorting mass ratios\nmass_1 = []\nmass_2 = []\nfor i in range(len(population['mass_1'])):\n    if population['mass_1'][i] > population['mass_2'][i]:\n        mass_1.append(population['mass_1'][i])\n        mass_2.append(population['mass_2'][i])\n    else:\n        mass_1.append(population['mass_2'][i])\n        mass_2.append(population['mass_1'][i])\nprint(mass_1)\nprint(mass_2)"

# %%
test = [[], [], []]
for i in range(len(test)):
    #test[i].append(i)
    test[0].append(i**1)
    #y
    test[1].append(i**2)
    #z
    test[2].append(i**3)
print(test)
# Out:
# [[0, 1, 2], [0, 1, 4], [0, 1, 8]]

# %%
# Converting spin_1 magnitude values into cartesian values
chiA_components = [[] for _ in range(len(spin_1))] 
theta = 0.0

for i in range(len(chiA_components)):
    #x component
    chiA_components[i].append(spin_1[i] * np.cos(theta))
    #y
    chiA_components[i].append(spin_1[i] * np.sin(theta))
    #z
    chiA_components[i].append(np.sqrt((chiA_components[i][0])**2.0 + (chiA_components[i][1])**2.0))
    
print(chiA_components)
# Out:
# [[-0.11952053589680162, -0.0, 0.11952053589680162], [0.016735043011588079, 0.0, 0.016735043011588079], [-0.12754192906269662, -0.0, 0.12754192906269662], [0.030296790372652871, 0.0, 0.030296790372652871], [-0.12361518487971353, -0.0, 0.12361518487971353], [-0.037426228087408392, -0.0, 0.037426228087408392], [-0.098962940504044, -0.0, 0.098962940504044], [-0.03713216135970937, -0.0, 0.03713216135970937], [-0.024173179206631354, -0.0, 0.024173179206631354], [-0.027970092537144144, -0.0, 0.027970092537144144], [0.68645271950476217, 0.0, 0.68645271950476217], [-0.12619827867910743, -0.0, 0.12619827867910743], [-0.11767692102616367, -0.0, 0.11767692102616367], [-0.12757754821868292, -0.0, 0.12757754821868292], [0.072796868751746083, 0.0, 0.072796868751746083]]

# %%
# Converting spin_2 magnitude values into cartesian values
chiA_components = [[] for _ in range(len(spin_2))] 
theta = 0.0

for i in range(len(chiA_components)):
    #x component
    chiA_components[i].append(spin_2[i] * np.cos(theta))
    #y
    chiA_components[i].append(spin_2[i] * np.sin(theta))
    #z
    chiA_components[i].append(np.sqrt((chiA_components[i][0])**2.0 + (chiA_components[i][1])**2.0))
    
print(chiA_components)
# Out:
# [[-0.058476736773766108, -0.0, 0.058476736773766108], [-0.018021012922494112, -0.0, 0.018021012922494112], [-0.15436625075946209, -0.0, 0.15436625075946209], [0.012061040772049225, 0.0, 0.012061040772049225], [0.053991717512588647, 0.0, 0.053991717512588647], [0.62437434718620377, 0.0, 0.62437434718620377], [-0.0014698393232112101, -0.0, 0.0014698393232112101], [0.0164226960661631, 0.0, 0.0164226960661631], [0.059059784883615685, 0.0, 0.059059784883615685], [-0.22044783670503673, -0.0, 0.22044783670503673], [-0.061551128262269841, -0.0, 0.061551128262269841], [-0.046429581059527159, -0.0, 0.046429581059527159], [0.65216986186775527, 0.0, 0.65216986186775527], [0.82820979216448898, 0.0, 0.82820979216448898], [0.055910292044030113, 0.0, 0.055910292044030113]]

# %%
population['mass_1'][0]
# Out:
# 10.510474631893103

# %%
print(population['spin_angle_1'][0] - population['spin_angle_2'][0])
# Out:
# 0.460558847882

# %%
for i in range(len(population['mass_1'])):
    mass_1 = population['mass_1'][i]
    mass_2 = population['mass_2'][i]
    spin_1 = population['spin_1'][i]
    spin_2 = population['spin_2'][i]
    spin_angle_1 = population['spin_angle_1'][i]
    spin_angle_2 = population['spin_angle_2'][i]
    phi_12 = population['spin_angle_2'][i] - population['spin_angle_1'][i]
    bin_sep = population['bin_sep'][i] * (1.e8 / (mass_1 + mass_2))
    bin_orb_inc = [0, 0, 1]

# %%
print("sur")
surrogate = fit_modeler.GPRFitters.read_from_file(f"surrogate.joblib")
# Out:
# sur

# %%
parameters = [mass_1, mass_2, spin_1, spin_2, spin_angle_1, spin_angle_2, phi_12, bin_sep, bin_orb_inc]
for i in parameters:
    print(i)
    print("")
# Out:
# 53.3811315668
#
# 13.5476823295
#
# 0.686013960203
#
# 0.0386934345316
#
# 0.0
#
# 0.412238819355
#
# 0.412238819355
#
# 129844186.074
#
# [0, 0, 1]

# %%
print("e")
M_f, spin_f, v_f = evolve_binary.evolve_binary(
    mass_1,
    mass_2,
    spin_1,
    spin_2,
    spin_angle_1,
    spin_angle_2,
    spin_angle_2 - spin_angle_1,
    bin_sep,
    bin_orb_inc,
    surrogate,
    True,
)

print("M_f = ", M_f)
print("spin_f = ", spin_f)
print("v_f = ", v_f)
# Out:
# e
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       1 print("e")
#       2 M_f, spin_f, v_f = evolve_binary.evolve_binary(
#       3     mass_1,
#       4     mass_2,
#       5     spin_1,
#       6     spin_2,
#       7     spin_angle_1,
#       8     spin_angle_2,
#       9     spin_angle_2 - spin_angle_1,
# ---> 10     bin_sep,
#      11     bin_orb_inc,
#      12     surrogate,
#      13     True,
#      14 )
#      16 print("M_f = ", M_f)
#      17 print("spin_f = ", spin_f)
#
# NameError: name 'bin_sep' is not defined

# %%
mass_1 = population['mass_1']
mass_2 = population['mass_2']
spin_1 = population['spin_1']
spin_2 = population['spin_2']
spin_angle_1 = population['spin_angle_1']
spin_angle_2 = population['spin_angle_2']
phi_12 = population['spin_angle_2'] - population['spin_angle_1']
bin_sep = population['bin_sep'] * (1.e8 / (mass_1 + mass_2))
bin_orb_inc = [0, 0, 1]

mass_final = []
spin_final = []
velocity_final =[]

# %%
import time

# %%
for i in range(len(mass_1)):
    start = time.time()
    M_f, spin_f, v_f = evolve_binary.evolve_binary(
        mass_1[i],
        mass_2[i],
        spin_1[i],
        spin_2[i],
        spin_angle_1[i],
        spin_angle_2[i],
        spin_angle_2[i] - spin_angle_1[i],
        1,
        [0,0,1],
        surrogate,
        True,
    )
    end = time.time()
    
    run_time = end - start

    mass_final.append(M_f)
    spin_final.append(spin_f)
    velocity_final.append(v_f)
    
    print("M_f = ", M_f)
    print("spin_f = ", spin_f)
    print("v_f = ", v_f)
    print("Merger took ", run_time, " seconds")

# %%
print(bin_sep)
# Out:
# 0    3.929177e+08
# 1    7.774826e+07
# 2    1.320129e+08
# 3    1.298442e+08
# dtype: float64

# %%
print(mass_final[-1])
print(spin_final[-1])
print(velocity_final[-1])
# Out:
# 65.4291225742
# [  4.38346003e-01   3.82077660e-01   2.03482924e+03]
# [ -1.07519672e-04   5.42113865e-04   6.99717987e-07]
